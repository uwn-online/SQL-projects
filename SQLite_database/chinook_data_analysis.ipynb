# %% [markdown]
# ##### Importing Data from Databases

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('Chinook.db.db')

# %%
query = "SELECT * FROM employee"
df = pd.read_sql(query, conn)
conn.close()
df.head()

# %%
df.describe()

# %%
df.info()

# %%
df.shape
